# %% [markdown]
# ## Setting up the Environment

# %%
import numpy as np
import random
import math

# %%
# sample products for recommendation categories and Q-table initialization
products = ["Electronics", "Clothing", "Books", "Groceries", "Toys"]
q_table = {product: 0 for product in products}
preferred_products = ["Electronics", "Books"]  # Products the user prefers

# %%
print(q_table)
# Out:
# {'Electronics': 0, 'Clothing': 0, 'Books': 0, 'Groceries': 0, 'Toys': 0}

# %% [markdown]
# ### Learning Parameters

# %%
alpha = 0.1  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.3  # Exploration rate (to prevent convergence)

# %% [markdown]
# ### Comparison Metrics

# %%
# helper function to compare pre and post poisoning model performance
def calculate_metrics(preferred_products):

    # Recommendation Accuracy (aligned recommendations)
    preferred_recommendations = sum([1 for product, q_value in q_table.items() if product in preferred_products and q_value > 0])
    accuracy = preferred_recommendations / len(preferred_products)
    print(f"\nRecommendation Accuracy: {accuracy:.2f}")

    # Entropy of Q-Values (consistency of preferences)
    q_values = list(q_table.values())
    total_q = sum(q_values)
    entropy = -sum((q / total_q) * math.log(q / total_q) if q > 0 else 0 for q in q_values)
    print(f"Entropy of Q-Values: {entropy:.2f}")

    # Average Q-Value for Preferred Products
    avg_preferred_q = np.mean([q_table[product] for product in preferred_products])
    print(f"Average Q-Value for Preferred Products: {avg_preferred_q:.2f}")

    # Average Q-Value Overall
    avg_q_value = np.mean(list(q_table.values()))
    print(f"Average Q-Value (Overall): {avg_q_value:.2f}")

# %%
# simulate user interaction with product recommendations
def user_interaction(product):

    # Higher chance of reward for preferred products, else neutral reward
    preferences = {"Electronics": 1, "Books": 1, "Clothing": 0, "Groceries": 0, "Toys": 0}

    # reward for agent based on user preference
    return preferences.get(product, 0)

# %% [markdown]
# ## Agent learns User Preferences

# %%
# model to simulate learning of the agent where user is the env
def train_agent(preferred_products,iterations=100):
    print("\n=== Training Agent with User Preferences ===")
    global q_table
    for i in range(iterations):
        product = random.choice(products) if random.uniform(0, 1) < epsilon else max(q_table, key=q_table.get)
        reward = user_interaction(product)

        # Update Q-table every 10 iterations
        q_table[product] += alpha * (reward + gamma * max(q_table.values()) - q_table[product])
        if i % 10 == 0:
            print(f"Iteration {i} - Q-Table: {q_table}")

    calculate_metrics(preferred_products)
    print("\nQ-Table after initial training:", q_table)

# %%
train_agent(preferred_products,iterations=500)
# Out:
# === Training Agent with User Preferences ===
# Iteration 0 - Q-Table: {'Electronics': 0.1, 'Clothing': 0, 'Books': 0, 'Groceries': 0, 'Toys': 0}
# Iteration 10 - Q-Table: {'Electronics': 0.8648275251635912, 'Clothing': 0, 'Books': 0, 'Groceries': 0.08593447726472322, 'Toys': 0}
# Iteration 20 - Q-Table: {'Electronics': 1.5705680661607317, 'Clothing': 0, 'Books': 0, 'Groceries': 0.1795946449937346, 'Toys': 0.09419557116715523}
# Iteration 30 - Q-Table: {'Electronics': 2.2995685419484477, 'Clothing': 0, 'Books': 0.29996077654076797, 'Groceries': 0.1795946449937346, 'Toys': 0.09419557116715523}
# Iteration 40 - Q-Table: {'Electronics': 2.822694674017249, 'Clothing': 0, 'Books': 0.6042343628372389, 'Groceries': 0.40915287813229284, 'Toys': 0.3322937116883714}
# Iteration 50 - Q-Table: {'Electronics': 3.2427095093971667, 'Clothing': 0.7311755578335326, 'Books': 0.6042343628372389, 'Groceries': 0.6477334130368934, 'Toys': 0.3322937116883714}
# Iteration 60 - Q-Table: {'Electronics': 3.7017636879676754, 'Clothing': 0.7311755578335326, 'Books': 1.26952236670185, 'Groceries': 0.6477334130368934, 'Toys': 0.6207138986432877}
# Iteration 70 - Q-Table: {'Electronics': 4.129632180625154, 'Clothing': 1.0080524864706006, 'Books': 1.8996383512455282, 'Groceries': 0.6477334130368934, 'Toys': 0.6207138986432877}
# Iteration 80 - Q-Table: {'Electronics': 4.528433576092386, 'Clothing': 1.5622446383676036, 'Books': 1.8996383512455282, 'Groceries': 0.9651407967539682, 'Toys': 0.6207138986432877}
# Iteration 90 - Q-Table: {'Electronics': 4.9511411121293, 'Clothing': 1.8516228746224803, 'Books': 1.8996383512455282, 'Groceries': 0.9651407967539682, 'Toys': 0.9950191030975357}
# Iteration 100 - Q-Table: {'Electronics': 5.198585434285785, 'Clothing': 2.1255593414564475, 'Books': 2.277547205206696, 'Groceries': 1.323271923438385, 'Toys': 1.6826621191288509}
# Iteration 110 - Q-Table: {'Electronics': 5.524767862361893, 'Clothing': 2.3979036366345166, 'Books': 2.626264507258941, 'Groceries': 1.323271923438385, 'Toys': 1.9951032095631516}
# Iteration 120 - Q-Table: {'Electronics': 5.952680273216761, 'Clothing': 2.3979036366345166, 'Books': 2.626264507258941, 'Groceries': 1.323271923438385, 'Toys': 1.9951032095631516}
# Iteration 130 - Q-Table: {'Electronics': 6.265357195457308, 'Clothing': 2.3979036366345166, 'Books': 3.366601829580152, 'Groceries': 1.323271923438385, 'Toys': 1.9951032095631516}
# Iteration 140 - Q-Table: {'Electronics': 6.588339384859575, 'Clothing': 2.747962307958299, 'Books': 3.366601829580152, 'Groceries': 1.323271923438385, 'Toys': 1.9951032095631516}
# Iteration 150 - Q-Table: {'Electronics': 6.820109361808565, 'Clothing': 3.0691871163534574, 'Books': 3.366601829580152, 'Groceries': 1.7838952757319082, 'Toys': 2.391613927797825}
# Iteration 160 - Q-Table: {'Electronics': 7.0951150569003625, 'Clothing': 3.0691871163534574, 'Books': 3.7494466733179084, 'Groceries': 1.7838952757319082, 'Toys': 2.391613927797825}
# Iteration 170 - Q-Table: {'Electronics': 7.372874127497718, 'Clothing': 3.0691871163534574, 'Books': 3.7494466733179084, 'Groceries': 1.7838952757319082, 'Toys': 2.391613927797825}
# Iteration 180 - Q-Table: {'Electronics': 7.501629435415474, 'Clothing': 3.4305322586305578, 'Books': 3.7494466733179084, 'Groceries': 3.122300183484334, 'Toys': 2.818375619778089}
# Iteration 190 - Q-Table: {'Electronics': 7.67135537051994, 'Clothing': 3.4305322586305578, 'Books': 4.160668706676654, 'Groceries': 3.485216814323293, 'Toys': 3.211684706987673}
# Iteration 200 - Q-Table: {'Electronics': 7.807627306335278, 'Clothing': 3.788172424252527, 'Books': 4.160668706676654, 'Groceries': 3.485216814323293, 'Toys': 4.22420372042102}
# Iteration 210 - Q-Table: {'Electronics': 7.997229731425107, 'Clothing': 3.788172424252527, 'Books': 4.160668706676654, 'Groceries': 3.841354725885437, 'Toys': 4.22420372042102}
# Iteration 220 - Q-Table: {'Electronics': 8.170434816909392, 'Clothing': 3.788172424252527, 'Books': 4.576597686964856, 'Groceries': 3.841354725885437, 'Toys': 4.22420372042102}
# Iteration 230 - Q-Table: {'Electronics': 8.328660649851164, 'Clothing': 3.788172424252527, 'Books': 4.576597686964856, 'Groceries': 3.841354725885437, 'Toys': 4.540399233143678}
# Iteration 240 - Q-Table: {'Electronics': 8.442202507132885, 'Clothing': 3.788172424252527, 'Books': 4.968517376754975, 'Groceries': 4.214170815017085, 'Toys': 4.835938768315915}
# Iteration 250 - Q-Table: {'Electronics': 8.562550628463754, 'Clothing': 3.788172424252527, 'Books': 4.968517376754975, 'Groceries': 4.558076468472123, 'Toys': 5.112143117126283}
# Iteration 260 - Q-Table: {'Electronics': 8.660203251420384, 'Clothing': 4.539916441038913, 'Books': 4.968517376754975, 'Groceries': 4.87547285001107, 'Toys': 5.112143117126283}
# Iteration 270 - Q-Table: {'Electronics': 8.751221877410488, 'Clothing': 4.539916441038913, 'Books': 4.968517376754975, 'Groceries': 5.174400281138189, 'Toys': 5.633063364717895}
# Iteration 280 - Q-Table: {'Electronics': 8.847696612862869, 'Clothing': 4.879042995714633, 'Books': 4.968517376754975, 'Groceries': 5.174400281138189, 'Toys': 5.862875227025717}
# Iteration 290 - Q-Table: {'Electronics': 8.957877471701247, 'Clothing': 4.879042995714633, 'Books': 4.968517376754975, 'Groceries': 5.174400281138189, 'Toys': 5.862875227025717}
# Iteration 300 - Q-Table: {'Electronics': 9.02867370309951, 'Clothing': 5.2019443621761825, 'Books': 4.968517376754975, 'Groceries': 5.730083182734786, 'Toys': 5.862875227025717}
# Iteration 310 - Q-Table: {'Electronics': 9.094660417148239, 'Clothing': 5.2019443621761825, 'Books': 5.384246272358434, 'Groceries': 5.974771266020238, 'Toys': 6.095107141866487}
# Iteration 320 - Q-Table: {'Electronics': 9.147640754278084, 'Clothing': 5.2019443621761825, 'Books': 6.1111530953049105, 'Groceries': 6.400140364843951, 'Toys': 6.095107141866487}
# Iteration 330 - Q-Table: {'Electronics': 9.205545483094465, 'Clothing': 5.510249019437066, 'Books': 6.427814647873916, 'Groceries': 6.58569242922073, 'Toys': 6.095107141866487}
# Iteration 340 - Q-Table: {'Electronics': 9.259516474304165, 'Clothing': 5.78914607901164, 'Books': 6.71703653242575, 'Groceries': 6.75980650214449, 'Toys': 6.095107141866487}
# Iteration 350 - Q-Table: {'Electronics': 9.316722755352888, 'Clothing': 5.78914607901164, 'Books': 6.71703653242575, 'Groceries': 6.75980650214449, 'Toys': 6.529072639121126}
# Iteration 360 - Q-Table: {'Electronics': 9.35021013901751, 'Clothing': 6.049351468612418, 'Books': 7.225127586518548, 'Groceries': 7.0686028579023805, 'Toys': 6.529072639121126}
# Iteration 370 - Q-Table: {'Electronics': 9.400409853285352, 'Clothing': 6.049351468612418, 'Books': 7.447556044880959, 'Groceries': 7.0686028579023805, 'Toys': 6.718848061361609}
# Iteration 380 - Q-Table: {'Electronics': 9.452264059554922, 'Clothing': 6.294622145347078, 'Books': 7.447556044880959, 'Groceries': 7.0686028579023805, 'Toys': 6.718848061361609}
# Iteration 390 - Q-Table: {'Electronics': 9.489474310107894, 'Clothing': 6.519212618722081, 'Books': 7.656853128302574, 'Groceries': 7.215795260021853, 'Toys': 6.718848061361609}
# Iteration 400 - Q-Table: {'Electronics': 9.528915128282907, 'Clothing': 6.519212618722081, 'Books': 7.656853128302574, 'Groceries': 7.350520297402152, 'Toys': 6.901930294645755}
# Iteration 410 - Q-Table: {'Electronics': 9.56965584465782, 'Clothing': 6.519212618722081, 'Books': 7.848770177017778, 'Groceries': 7.350520297402152, 'Toys': 6.901930294645755}
# Iteration 420 - Q-Table: {'Electronics': 9.598891125131251, 'Clothing': 6.519212618722081, 'Books': 8.025162185335205, 'Groceries': 7.594307503935052, 'Toys': 6.901930294645755}
# Iteration 430 - Q-Table: {'Electronics': 9.626140316996878, 'Clothing': 6.733304112940498, 'Books': 8.025162185335205, 'Groceries': 7.699495340798249, 'Toys': 7.0763558524378825}
# Iteration 440 - Q-Table: {'Electronics': 9.6515383444933, 'Clothing': 6.733304112940498, 'Books': 8.025162185335205, 'Groceries': 7.7958984352481435, 'Toys': 7.379887273832641}
# Iteration 450 - Q-Table: {'Electronics': 9.675210965827903, 'Clothing': 6.733304112940498, 'Books': 8.191908512631095, 'Groceries': 7.7958984352481435, 'Toys': 7.629357518875801}
# Iteration 460 - Q-Table: {'Electronics': 9.68800894968253, 'Clothing': 7.109282182916257, 'Books': 8.481298688151295, 'Groceries': 7.7958984352481435, 'Toys': 7.835655563110566}
# Iteration 470 - Q-Table: {'Electronics': 9.714990794474456, 'Clothing': 7.272182320407409, 'Books': 8.481298688151295, 'Groceries': 7.7958984352481435, 'Toys': 7.835655563110566}
# Iteration 480 - Q-Table: {'Electronics': 9.726221294358892, 'Clothing': 7.272182320407409, 'Books': 8.918661381498165, 'Groceries': 7.7958984352481435, 'Toys': 8.009137144688365}
# Iteration 490 - Q-Table: {'Electronics': 9.7498984304031, 'Clothing': 7.421294922463105, 'Books': 8.918661381498165, 'Groceries': 7.7958984352481435, 'Toys': 8.009137144688365}
#
# Recommendation Accuracy: 1.00
# Entropy of Q-Values: 1.60
# Average Q-Value for Preferred Products: 9.38
# Average Q-Value (Overall): 8.43
#
# Q-Table after initial training: {'Electronics': 9.764534336890485, 'Clothing': 7.421294922463105, 'Books': 9.005173052061892, 'Groceries': 7.893799450459608, 'Toys': 8.086817460845936}

# %% [markdown]
# ## Agent unlearns User Preferences

# %% [markdown]
# ### Poisoning the Environment

# %%
# Introduce random reward values to confuse agent
def poison_environment_random():
    product = random.choice(products)
    reward = random.uniform(-1, 1)
    print(f"Insertion of random rewards for product '{product}'")
    return product, reward

# %%
# Invert policy by ranking low-reward actions higher
def poison_environment_policy_bias():
    product = min(q_table, key=q_table.get)
    reward = -q_table[product]  # Assign negative reward to mislead agent
    print(f"Biased policy poisoning with low-reward product '{product}'")
    return product, reward

# %%
# Change the environment by randomly increasing or decreasing user preferences
def modify_environment():
    product = random.choice(list(q_table.keys()))

    # Introduce a modified reward that contradicts actual user preferences
    modified_reward = random.uniform(-1, 1)
    print(f"Modify Environment: Assigning contradictory reward for '{product}' as {modified_reward:.4f}")
    return product, modified_reward

# %% [markdown]
# ### Manipulating Q-table

# %%
# Directly change Q-table values to disrupt convergence
def sabotage_q_table():
    # Randomly pick a product to sabotage its Q-value
    product = random.choice(list(q_table.keys()))

    # Assign a random low Q-value to reduce its attractiveness
    sabotaged_value = random.uniform(0, 0.5)
    q_table[product] = sabotaged_value
    print(f"Sabotage Q-table: Setting Q-value of '{product}' to {sabotaged_value:.4f}")

    # Return sabotaged product and a negative reward to simulate sabotage
    reward = -0.5  # Arbitrary negative reward to enforce misalignment
    return product, reward

# %% [markdown]
# ### Apply different Poisoning Strategies

# %%
def apply_poisoning(preferred_products, iterations=50):
    global q_table
    print("\n=== Applying Poisoning Techniques ===")
    for i in range(iterations):
        if i % 10 == 0:
            product, reward = poison_environment_random()
        elif i % 10 == 1:
            product, reward = poison_environment_policy_bias()
        elif i % 10 == 2:
            product, reward = sabotage_q_table()
        else:
            product, reward = modify_environment()

        if product in q_table:
            # Q-learning update with poisoned data
            q_table[product] += alpha * (reward + gamma * max(q_table.values()) - q_table[product])
            print(f"Iteration {i}: Poisoning - Updated Q-value of '{product}' to {q_table[product]:.4f}")
        else:
            print(f"Iteration {i}: Skipping update due to undefined product.")

        if i % 10 == 0:
            print(f"Q-table after {i} iterations: {q_table}")

    print("\n=== Performance Metrics After Poisoning ===")
    calculate_metrics(preferred_products)

# %%
apply_poisoning(preferred_products, iterations=300)
# Out:
# === Applying Poisoning Techniques ===
# Insertion of random rewards for product 'Books'
# Iteration 0: Poisoning - Updated Q-value of 'Books' to 9.0001
# Q-table after 0 iterations: {'Electronics': 9.764534336890485, 'Clothing': 7.421294922463105, 'Books': 9.000075150602564, 'Groceries': 7.893799450459608, 'Toys': 8.086817460845936}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 1: Poisoning - Updated Q-value of 'Clothing' to 6.8158
# Sabotage Q-table: Setting Q-value of 'Books' to 0.3308
# Iteration 2: Poisoning - Updated Q-value of 'Books' to 1.1265
# Modify Environment: Assigning contradictory reward for 'Books' as 0.9086
# Iteration 3: Poisoning - Updated Q-value of 'Books' to 1.9836
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.4978
# Iteration 4: Poisoning - Updated Q-value of 'Groceries' to 7.9334
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.0966
# Iteration 5: Poisoning - Updated Q-value of 'Clothing' to 7.0227
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.4505
# Iteration 6: Poisoning - Updated Q-value of 'Electronics' to 9.7119
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.3850
# Iteration 7: Poisoning - Updated Q-value of 'Toys' to 8.1137
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.4926
# Iteration 8: Poisoning - Updated Q-value of 'Clothing' to 7.1453
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.9266
# Iteration 9: Poisoning - Updated Q-value of 'Toys' to 8.0838
# Insertion of random rewards for product 'Books'
# Iteration 10: Poisoning - Updated Q-value of 'Books' to 2.6802
# Q-table after 10 iterations: {'Electronics': 9.711940684350571, 'Clothing': 7.1452703892291325, 'Books': 2.6802452713475047, 'Groceries': 7.93344370975224, 'Toys': 8.0837547606369}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 11: Poisoning - Updated Q-value of 'Books' to 3.0183
# Sabotage Q-table: Setting Q-value of 'Books' to 0.0421
# Iteration 12: Poisoning - Updated Q-value of 'Books' to 0.8619
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.8577
# Iteration 13: Poisoning - Updated Q-value of 'Electronics' to 9.7006
# Modify Environment: Assigning contradictory reward for 'Books' as 0.8986
# Iteration 14: Poisoning - Updated Q-value of 'Books' to 1.7387
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.0582
# Iteration 15: Poisoning - Updated Q-value of 'Electronics' to 9.6094
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.9453
# Iteration 16: Poisoning - Updated Q-value of 'Clothing' to 7.3901
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.8675
# Iteration 17: Poisoning - Updated Q-value of 'Electronics' to 9.4266
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.8630
# Iteration 18: Poisoning - Updated Q-value of 'Groceries' to 8.0748
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2646
# Iteration 19: Poisoning - Updated Q-value of 'Books' to 2.4396
# Insertion of random rewards for product 'Clothing'
# Iteration 20: Poisoning - Updated Q-value of 'Clothing' to 7.5521
# Q-table after 20 iterations: {'Electronics': 9.426560487356326, 'Clothing': 7.55208813025187, 'Books': 2.439644084238994, 'Groceries': 8.074791406439392, 'Toys': 8.0837547606369}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 21: Poisoning - Updated Q-value of 'Books' to 2.8001
# Sabotage Q-table: Setting Q-value of 'Electronics' to 0.2929
# Iteration 22: Poisoning - Updated Q-value of 'Electronics' to 0.9412
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.8067
# Iteration 23: Poisoning - Updated Q-value of 'Clothing' to 7.6051
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.1059
# Iteration 24: Poisoning - Updated Q-value of 'Electronics' to 1.5640
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.1028
# Iteration 25: Poisoning - Updated Q-value of 'Toys' to 8.0132
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.3273
# Iteration 26: Poisoning - Updated Q-value of 'Clothing' to 7.6040
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.6320
# Iteration 27: Poisoning - Updated Q-value of 'Electronics' to 2.0711
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.3613
# Iteration 28: Poisoning - Updated Q-value of 'Clothing' to 7.5342
# Modify Environment: Assigning contradictory reward for 'Books' as 0.8656
# Iteration 29: Poisoning - Updated Q-value of 'Books' to 3.3334
# Insertion of random rewards for product 'Groceries'
# Iteration 30: Poisoning - Updated Q-value of 'Groceries' to 7.8945
# Q-table after 30 iterations: {'Electronics': 2.071139666434667, 'Clothing': 7.534239144079623, 'Books': 3.3333885216089665, 'Groceries': 7.894482968729034, 'Toys': 8.01319700538505}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 31: Poisoning - Updated Q-value of 'Electronics' to 2.3781
# Sabotage Q-table: Setting Q-value of 'Toys' to 0.3919
# Iteration 32: Poisoning - Updated Q-value of 'Toys' to 1.0132
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3634
# Iteration 33: Poisoning - Updated Q-value of 'Electronics' to 2.8145
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.9492
# Iteration 34: Poisoning - Updated Q-value of 'Groceries' to 7.9105
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0245
# Iteration 35: Poisoning - Updated Q-value of 'Groceries' to 7.8338
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.3888
# Iteration 36: Poisoning - Updated Q-value of 'Clothing' to 7.5247
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.4314
# Iteration 37: Poisoning - Updated Q-value of 'Electronics' to 3.2812
# Modify Environment: Assigning contradictory reward for 'Books' as -0.2729
# Iteration 38: Poisoning - Updated Q-value of 'Books' to 3.6778
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.3455
# Iteration 39: Poisoning - Updated Q-value of 'Groceries' to 7.7900
# Insertion of random rewards for product 'Clothing'
# Iteration 40: Poisoning - Updated Q-value of 'Clothing' to 7.5139
# Q-table after 40 iterations: {'Electronics': 3.2811936225962692, 'Clothing': 7.513903712556274, 'Books': 3.6777980663464414, 'Groceries': 7.79001407069717, 'Toys': 1.0132080759483215}
# Biased policy poisoning with low-reward product 'Toys'
# Iteration 41: Poisoning - Updated Q-value of 'Toys' to 1.5117
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.4335
# Iteration 42: Poisoning - Updated Q-value of 'Groceries' to 1.0164
# Modify Environment: Assigning contradictory reward for 'Books' as 0.7837
# Iteration 43: Poisoning - Updated Q-value of 'Books' to 4.0646
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.4354
# Iteration 44: Poisoning - Updated Q-value of 'Groceries' to 1.6346
# Modify Environment: Assigning contradictory reward for 'Books' as -0.3723
# Iteration 45: Poisoning - Updated Q-value of 'Books' to 4.2972
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.9140
# Iteration 46: Poisoning - Updated Q-value of 'Electronics' to 3.5379
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.0125
# Iteration 47: Poisoning - Updated Q-value of 'Clothing' to 7.4375
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.5828
# Iteration 48: Poisoning - Updated Q-value of 'Toys' to 2.0882
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.7042
# Iteration 49: Poisoning - Updated Q-value of 'Groceries' to 2.2109
# Insertion of random rewards for product 'Clothing'
# Iteration 50: Poisoning - Updated Q-value of 'Clothing' to 7.3459
# Q-table after 50 iterations: {'Electronics': 3.5379250815217658, 'Clothing': 7.345865085419815, 'Books': 4.297194738942195, 'Groceries': 2.2109070292540216, 'Toys': 2.088156331398312}
# Biased policy poisoning with low-reward product 'Toys'
# Iteration 51: Poisoning - Updated Q-value of 'Toys' to 2.3317
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.4968
# Iteration 52: Poisoning - Updated Q-value of 'Clothing' to 0.7839
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.5525
# Iteration 53: Poisoning - Updated Q-value of 'Groceries' to 2.3213
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.4428
# Iteration 54: Poisoning - Updated Q-value of 'Toys' to 2.5295
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.2448
# Iteration 55: Poisoning - Updated Q-value of 'Groceries' to 2.4515
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.2265
# Iteration 56: Poisoning - Updated Q-value of 'Electronics' to 3.5935
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.2075
# Iteration 57: Poisoning - Updated Q-value of 'Toys' to 2.6841
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.4564
# Iteration 58: Poisoning - Updated Q-value of 'Groceries' to 2.5474
# Modify Environment: Assigning contradictory reward for 'Books' as 0.4437
# Iteration 59: Poisoning - Updated Q-value of 'Books' to 4.2986
# Insertion of random rewards for product 'Groceries'
# Iteration 60: Poisoning - Updated Q-value of 'Groceries' to 2.7423
# Q-table after 60 iterations: {'Electronics': 3.593525728583696, 'Clothing': 0.7838791617261536, 'Books': 4.298596192876314, 'Groceries': 2.7422873587705965, 'Toys': 2.684066140025264}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 61: Poisoning - Updated Q-value of 'Clothing' to 1.0140
# Sabotage Q-table: Setting Q-value of 'Electronics' to 0.0650
# Iteration 62: Poisoning - Updated Q-value of 'Electronics' to 0.3954
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3070
# Iteration 63: Poisoning - Updated Q-value of 'Electronics' to 0.7120
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.6124
# Iteration 64: Poisoning - Updated Q-value of 'Electronics' to 1.0889
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.3363
# Iteration 65: Poisoning - Updated Q-value of 'Groceries' to 2.8213
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.8347
# Iteration 66: Poisoning - Updated Q-value of 'Groceries' to 2.8426
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.0726
# Iteration 67: Poisoning - Updated Q-value of 'Clothing' to 1.2922
# Modify Environment: Assigning contradictory reward for 'Books' as 0.3697
# Iteration 68: Poisoning - Updated Q-value of 'Books' to 4.2926
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.2297
# Iteration 69: Poisoning - Updated Q-value of 'Groceries' to 2.9676
# Insertion of random rewards for product 'Electronics'
# Iteration 70: Poisoning - Updated Q-value of 'Electronics' to 1.4479
# Q-table after 70 iterations: {'Electronics': 1.44788913404259, 'Clothing': 1.2921923655914302, 'Books': 4.292579455207895, 'Groceries': 2.967612969643264, 'Toys': 2.684066140025264}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 71: Poisoning - Updated Q-value of 'Clothing' to 1.4201
# Sabotage Q-table: Setting Q-value of 'Books' to 0.1381
# Iteration 72: Poisoning - Updated Q-value of 'Books' to 0.3414
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.2707
# Iteration 73: Poisoning - Updated Q-value of 'Toys' to 2.6557
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.4204
# Iteration 74: Poisoning - Updated Q-value of 'Toys' to 2.6152
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.7513
# Iteration 75: Poisoning - Updated Q-value of 'Groceries' to 3.0131
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.3667
# Iteration 76: Poisoning - Updated Q-value of 'Toys' to 2.6615
# Modify Environment: Assigning contradictory reward for 'Books' as -0.3725
# Iteration 77: Poisoning - Updated Q-value of 'Books' to 0.5412
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.2062
# Iteration 78: Poisoning - Updated Q-value of 'Toys' to 2.6871
# Modify Environment: Assigning contradictory reward for 'Books' as 0.1484
# Iteration 79: Poisoning - Updated Q-value of 'Books' to 0.7731
# Insertion of random rewards for product 'Toys'
# Iteration 80: Poisoning - Updated Q-value of 'Toys' to 2.7263
# Q-table after 80 iterations: {'Electronics': 1.44788913404259, 'Clothing': 1.4200860434418547, 'Books': 0.7730641599583383, 'Groceries': 3.013062436961809, 'Toys': 2.7262671050352933}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 81: Poisoning - Updated Q-value of 'Books' to 0.8896
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.2947
# Iteration 82: Poisoning - Updated Q-value of 'Clothing' to 0.4864
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2586
# Iteration 83: Poisoning - Updated Q-value of 'Books' to 1.0977
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.5185
# Iteration 84: Poisoning - Updated Q-value of 'Clothing' to 0.7608
# Modify Environment: Assigning contradictory reward for 'Books' as 0.9974
# Iteration 85: Poisoning - Updated Q-value of 'Books' to 1.3588
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.1741
# Iteration 86: Poisoning - Updated Q-value of 'Groceries' to 2.9655
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.3645
# Iteration 87: Poisoning - Updated Q-value of 'Clothing' to 0.9151
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3722
# Iteration 88: Poisoning - Updated Q-value of 'Electronics' to 1.5328
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.3090
# Iteration 89: Poisoning - Updated Q-value of 'Toys' to 2.7514
# Insertion of random rewards for product 'Electronics'
# Iteration 90: Poisoning - Updated Q-value of 'Electronics' to 1.5873
# Q-table after 90 iterations: {'Electronics': 1.587297487598361, 'Clothing': 0.9151452086670828, 'Books': 1.3588427543486605, 'Groceries': 2.9655243893389933, 'Toys': 2.7514370090730607}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 91: Poisoning - Updated Q-value of 'Clothing' to 0.9990
# Sabotage Q-table: Setting Q-value of 'Toys' to 0.3510
# Iteration 92: Poisoning - Updated Q-value of 'Toys' to 0.5328
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.6261
# Iteration 93: Poisoning - Updated Q-value of 'Electronics' to 1.6329
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.8217
# Iteration 94: Poisoning - Updated Q-value of 'Groceries' to 2.8537
# Modify Environment: Assigning contradictory reward for 'Books' as -0.5719
# Iteration 95: Poisoning - Updated Q-value of 'Books' to 1.4226
# Modify Environment: Assigning contradictory reward for 'Books' as -0.1224
# Iteration 96: Poisoning - Updated Q-value of 'Books' to 1.5249
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.8708
# Iteration 97: Poisoning - Updated Q-value of 'Toys' to 0.6493
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.8393
# Iteration 98: Poisoning - Updated Q-value of 'Electronics' to 1.6425
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.2389
# Iteration 99: Poisoning - Updated Q-value of 'Groceries' to 2.8491
# Insertion of random rewards for product 'Toys'
# Iteration 100: Poisoning - Updated Q-value of 'Toys' to 0.9237
# Q-table after 100 iterations: {'Electronics': 1.6424728906588668, 'Clothing': 0.9990133619741757, 'Books': 1.5249262374264867, 'Groceries': 2.8490593816869434, 'Toys': 0.9237230781621917}
# Biased policy poisoning with low-reward product 'Toys'
# Iteration 101: Poisoning - Updated Q-value of 'Toys' to 0.9954
# Sabotage Q-table: Setting Q-value of 'Electronics' to 0.0617
# Iteration 102: Poisoning - Updated Q-value of 'Electronics' to 0.2620
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.1997
# Iteration 103: Poisoning - Updated Q-value of 'Clothing' to 1.1356
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.0896
# Iteration 104: Poisoning - Updated Q-value of 'Toys' to 1.1612
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.2766
# Iteration 105: Poisoning - Updated Q-value of 'Groceries' to 2.7929
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.8625
# Iteration 106: Poisoning - Updated Q-value of 'Clothing' to 1.3596
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.5098
# Iteration 107: Poisoning - Updated Q-value of 'Electronics' to 0.4362
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.7558
# Iteration 108: Poisoning - Updated Q-value of 'Toys' to 1.2209
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.9412
# Iteration 109: Poisoning - Updated Q-value of 'Toys' to 1.4443
# Insertion of random rewards for product 'Clothing'
# Iteration 110: Poisoning - Updated Q-value of 'Clothing' to 1.4404
# Q-table after 110 iterations: {'Electronics': 0.43617080507493655, 'Clothing': 1.440405310510562, 'Books': 1.5249262374264867, 'Groceries': 2.792907163932228, 'Toys': 1.4442802892897886}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 111: Poisoning - Updated Q-value of 'Electronics' to 0.6003
# Sabotage Q-table: Setting Q-value of 'Toys' to 0.0123
# Iteration 112: Poisoning - Updated Q-value of 'Toys' to 0.2125
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2287
# Iteration 113: Poisoning - Updated Q-value of 'Books' to 1.6467
# Modify Environment: Assigning contradictory reward for 'Books' as -0.0299
# Iteration 114: Poisoning - Updated Q-value of 'Books' to 1.7304
# Modify Environment: Assigning contradictory reward for 'Books' as -0.4807
# Iteration 115: Poisoning - Updated Q-value of 'Books' to 1.7606
# Modify Environment: Assigning contradictory reward for 'Books' as -0.9121
# Iteration 116: Poisoning - Updated Q-value of 'Books' to 1.7447
# Modify Environment: Assigning contradictory reward for 'Books' as -0.9794
# Iteration 117: Poisoning - Updated Q-value of 'Books' to 1.7237
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0019
# Iteration 118: Poisoning - Updated Q-value of 'Groceries' to 2.7652
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.2361
# Iteration 119: Poisoning - Updated Q-value of 'Toys' to 0.4637
# Insertion of random rewards for product 'Toys'
# Iteration 120: Poisoning - Updated Q-value of 'Toys' to 0.6314
# Q-table after 120 iterations: {'Electronics': 0.6002982888138497, 'Clothing': 1.440405310510562, 'Books': 1.7236566494543357, 'Groceries': 2.7651685394101237, 'Toys': 0.631363352802325}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 121: Poisoning - Updated Q-value of 'Electronics' to 0.7291
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.2646
# Iteration 122: Poisoning - Updated Q-value of 'Groceries' to 0.3433
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.9055
# Iteration 123: Poisoning - Updated Q-value of 'Clothing' to 1.5420
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.7165
# Iteration 124: Poisoning - Updated Q-value of 'Groceries' to 0.5357
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3202
# Iteration 125: Poisoning - Updated Q-value of 'Electronics' to 0.7793
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.8468
# Iteration 126: Poisoning - Updated Q-value of 'Electronics' to 0.9412
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.1914
# Iteration 127: Poisoning - Updated Q-value of 'Clothing' to 1.5621
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.1010
# Iteration 128: Poisoning - Updated Q-value of 'Groceries' to 0.6474
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.7458
# Iteration 129: Poisoning - Updated Q-value of 'Groceries' to 0.8124
# Insertion of random rewards for product 'Electronics'
# Iteration 130: Poisoning - Updated Q-value of 'Electronics' to 1.0592
# Q-table after 130 iterations: {'Electronics': 1.0591797123875577, 'Clothing': 1.562111229853894, 'Books': 1.7236566494543357, 'Groceries': 0.8123754529375873, 'Toys': 0.631363352802325}
# Biased policy poisoning with low-reward product 'Toys'
# Iteration 131: Poisoning - Updated Q-value of 'Toys' to 0.6602
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.2851
# Iteration 132: Poisoning - Updated Q-value of 'Clothing' to 0.3617
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0415
# Iteration 133: Poisoning - Updated Q-value of 'Groceries' to 0.8904
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.8689
# Iteration 134: Poisoning - Updated Q-value of 'Groceries' to 0.8696
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.3095
# Iteration 135: Poisoning - Updated Q-value of 'Clothing' to 0.5116
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.8545
# Iteration 136: Poisoning - Updated Q-value of 'Groceries' to 1.0232
# Modify Environment: Assigning contradictory reward for 'Books' as 0.4772
# Iteration 137: Poisoning - Updated Q-value of 'Books' to 1.7541
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.0515
# Iteration 138: Poisoning - Updated Q-value of 'Toys' to 0.7469
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.2393
# Iteration 139: Poisoning - Updated Q-value of 'Toys' to 0.8540
# Insertion of random rewards for product 'Electronics'
# Iteration 140: Poisoning - Updated Q-value of 'Electronics' to 1.0349
# Q-table after 140 iterations: {'Electronics': 1.0348901999801408, 'Clothing': 0.511629088727719, 'Books': 1.7541438153345763, 'Groceries': 1.0232268907999573, 'Toys': 0.8540345695147791}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 141: Poisoning - Updated Q-value of 'Clothing' to 0.5672
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.4001
# Iteration 142: Poisoning - Updated Q-value of 'Clothing' to 0.4680
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2639
# Iteration 143: Poisoning - Updated Q-value of 'Books' to 1.7630
# Modify Environment: Assigning contradictory reward for 'Books' as -0.1829
# Iteration 144: Poisoning - Updated Q-value of 'Books' to 1.7271
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.8376
# Iteration 145: Poisoning - Updated Q-value of 'Clothing' to 0.6604
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.8247
# Iteration 146: Poisoning - Updated Q-value of 'Groceries' to 0.9939
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.6631
# Iteration 147: Poisoning - Updated Q-value of 'Electronics' to 1.0205
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.5814
# Iteration 148: Poisoning - Updated Q-value of 'Toys' to 0.9822
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.4121
# Iteration 149: Poisoning - Updated Q-value of 'Clothing' to 0.7910
# Insertion of random rewards for product 'Groceries'
# Iteration 150: Poisoning - Updated Q-value of 'Groceries' to 1.1455
# Q-table after 150 iterations: {'Electronics': 1.0205238926362743, 'Clothing': 0.7909938155997522, 'Books': 1.7270721526390294, 'Groceries': 1.1455193894016498, 'Toys': 0.9822101170338445}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 151: Poisoning - Updated Q-value of 'Clothing' to 0.7882
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.1188
# Iteration 152: Poisoning - Updated Q-value of 'Groceries' to 0.2123
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.5995
# Iteration 153: Poisoning - Updated Q-value of 'Toys' to 0.9795
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.6562
# Iteration 154: Poisoning - Updated Q-value of 'Electronics' to 1.1395
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.6591
# Iteration 155: Poisoning - Updated Q-value of 'Groceries' to 0.2806
# Modify Environment: Assigning contradictory reward for 'Books' as -0.2918
# Iteration 156: Poisoning - Updated Q-value of 'Books' to 1.6806
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.1206
# Iteration 157: Poisoning - Updated Q-value of 'Electronics' to 1.1889
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.5988
# Iteration 158: Poisoning - Updated Q-value of 'Clothing' to 0.8008
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.0509
# Iteration 159: Poisoning - Updated Q-value of 'Electronics' to 1.2263
# Insertion of random rewards for product 'Books'
# Iteration 160: Poisoning - Updated Q-value of 'Books' to 1.5811
# Q-table after 160 iterations: {'Electronics': 1.2263462792360769, 'Clothing': 0.8007835572144554, 'Books': 1.5810972049637415, 'Groceries': 0.28061458078905044, 'Toys': 0.9794750081518415}
# Biased policy poisoning with low-reward product 'Groceries'
# Iteration 161: Poisoning - Updated Q-value of 'Groceries' to 0.3668
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.3220
# Iteration 162: Poisoning - Updated Q-value of 'Groceries' to 0.3821
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.9026
# Iteration 163: Poisoning - Updated Q-value of 'Electronics' to 1.1557
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.6641
# Iteration 164: Poisoning - Updated Q-value of 'Clothing' to 0.9294
# Modify Environment: Assigning contradictory reward for 'Books' as -0.3360
# Iteration 165: Poisoning - Updated Q-value of 'Books' to 1.5317
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.2997
# Iteration 166: Poisoning - Updated Q-value of 'Electronics' to 1.1481
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.7908
# Iteration 167: Poisoning - Updated Q-value of 'Electronics' to 1.2502
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.3486
# Iteration 168: Poisoning - Updated Q-value of 'Groceries' to 0.4469
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.5541
# Iteration 169: Poisoning - Updated Q-value of 'Electronics' to 1.3184
# Insertion of random rewards for product 'Groceries'
# Iteration 170: Poisoning - Updated Q-value of 'Groceries' to 0.6221
# Q-table after 170 iterations: {'Electronics': 1.3184231644322033, 'Clothing': 0.9294108607092566, 'Books': 1.531682338602017, 'Groceries': 0.6220654466210739, 'Toys': 0.9794750081518415}
# Biased policy poisoning with low-reward product 'Groceries'
# Iteration 171: Poisoning - Updated Q-value of 'Groceries' to 0.6355
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.3250
# Iteration 172: Poisoning - Updated Q-value of 'Clothing' to 0.3804
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.3472
# Iteration 173: Poisoning - Updated Q-value of 'Electronics' to 1.3592
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.0915
# Iteration 174: Poisoning - Updated Q-value of 'Toys' to 1.0285
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.6468
# Iteration 175: Poisoning - Updated Q-value of 'Electronics' to 1.2964
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.7279
# Iteration 176: Poisoning - Updated Q-value of 'Electronics' to 1.2318
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.5071
# Iteration 177: Poisoning - Updated Q-value of 'Electronics' to 1.2972
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.1718
# Iteration 178: Poisoning - Updated Q-value of 'Electronics' to 1.3225
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.7733
# Iteration 179: Poisoning - Updated Q-value of 'Groceries' to 0.6325
# Insertion of random rewards for product 'Books'
# Iteration 180: Poisoning - Updated Q-value of 'Books' to 1.4234
# Q-table after 180 iterations: {'Electronics': 1.3225213832003586, 'Clothing': 0.38036094767202194, 'Books': 1.4233934779722701, 'Groceries': 0.632472548047734, 'Toys': 1.0285257986081304}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 181: Poisoning - Updated Q-value of 'Clothing' to 0.4324
# Sabotage Q-table: Setting Q-value of 'Electronics' to 0.0035
# Iteration 182: Poisoning - Updated Q-value of 'Electronics' to 0.0812
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.5189
# Iteration 183: Poisoning - Updated Q-value of 'Electronics' to 0.1493
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.8824
# Iteration 184: Poisoning - Updated Q-value of 'Electronics' to 0.3507
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.6345
# Iteration 185: Poisoning - Updated Q-value of 'Groceries' to 0.7608
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.5038
# Iteration 186: Poisoning - Updated Q-value of 'Electronics' to 0.4941
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2084
# Iteration 187: Poisoning - Updated Q-value of 'Books' to 1.4300
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.0399
# Iteration 188: Poisoning - Updated Q-value of 'Clothing' to 0.5218
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.9762
# Iteration 189: Poisoning - Updated Q-value of 'Clothing' to 0.6960
# Insertion of random rewards for product 'Toys'
# Iteration 190: Poisoning - Updated Q-value of 'Toys' to 1.0709
# Q-table after 190 iterations: {'Electronics': 0.49413444079713037, 'Clothing': 0.6959779732227713, 'Books': 1.4299996582313836, 'Groceries': 0.760780332989693, 'Toys': 1.0709335981570443}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 191: Poisoning - Updated Q-value of 'Electronics' to 0.5240
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.4237
# Iteration 192: Poisoning - Updated Q-value of 'Clothing' to 0.4600
# Modify Environment: Assigning contradictory reward for 'Books' as 0.6202
# Iteration 193: Poisoning - Updated Q-value of 'Books' to 1.4777
# Modify Environment: Assigning contradictory reward for 'Books' as -0.1481
# Iteration 194: Poisoning - Updated Q-value of 'Books' to 1.4481
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.4113
# Iteration 195: Poisoning - Updated Q-value of 'Toys' to 1.1353
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.3968
# Iteration 196: Poisoning - Updated Q-value of 'Groceries' to 0.8547
# Modify Environment: Assigning contradictory reward for 'Books' as -0.8740
# Iteration 197: Poisoning - Updated Q-value of 'Books' to 1.3462
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.6864
# Iteration 198: Poisoning - Updated Q-value of 'Groceries' to 0.8218
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.4688
# Iteration 199: Poisoning - Updated Q-value of 'Groceries' to 0.9076
# Insertion of random rewards for product 'Groceries'
# Iteration 200: Poisoning - Updated Q-value of 'Groceries' to 0.9935
# Q-table after 200 iterations: {'Electronics': 0.5240075218785288, 'Clothing': 0.46004553225646394, 'Books': 1.346248408015351, 'Groceries': 0.9934759180961098, 'Toys': 1.1352979880101646}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 201: Poisoning - Updated Q-value of 'Clothing' to 0.4892
# Sabotage Q-table: Setting Q-value of 'Books' to 0.2176
# Iteration 202: Poisoning - Updated Q-value of 'Books' to 0.2480
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.4704
# Iteration 203: Poisoning - Updated Q-value of 'Electronics' to 0.6208
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.2153
# Iteration 204: Poisoning - Updated Q-value of 'Clothing' to 0.5640
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.1886
# Iteration 205: Poisoning - Updated Q-value of 'Groceries' to 0.9774
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.6423
# Iteration 206: Poisoning - Updated Q-value of 'Groceries' to 0.9176
# Modify Environment: Assigning contradictory reward for 'Books' as -0.5842
# Iteration 207: Poisoning - Updated Q-value of 'Books' to 0.2670
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0314
# Iteration 208: Poisoning - Updated Q-value of 'Groceries' to 0.9312
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0145
# Iteration 209: Poisoning - Updated Q-value of 'Groceries' to 0.9417
# Insertion of random rewards for product 'Books'
# Iteration 210: Poisoning - Updated Q-value of 'Books' to 0.4140
# Q-table after 210 iterations: {'Electronics': 0.6208255929297979, 'Clothing': 0.5639887879106498, 'Books': 0.4140126628879002, 'Groceries': 0.9417075355944087, 'Toys': 1.1352979880101646}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 211: Poisoning - Updated Q-value of 'Books' to 0.4334
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.1055
# Iteration 212: Poisoning - Updated Q-value of 'Groceries' to 0.1471
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.1312
# Iteration 213: Poisoning - Updated Q-value of 'Groceries' to 0.2477
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.2584
# Iteration 214: Poisoning - Updated Q-value of 'Groceries' to 0.2993
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.1084
# Iteration 215: Poisoning - Updated Q-value of 'Electronics' to 0.6501
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.9184
# Iteration 216: Poisoning - Updated Q-value of 'Toys' to 1.0321
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.1251
# Iteration 217: Poisoning - Updated Q-value of 'Clothing' to 0.5880
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.5433
# Iteration 218: Poisoning - Updated Q-value of 'Groceries' to 0.4166
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.6831
# Iteration 219: Poisoning - Updated Q-value of 'Toys' to 0.9535
# Insertion of random rewards for product 'Groceries'
# Iteration 220: Poisoning - Updated Q-value of 'Groceries' to 0.3742
# Q-table after 220 iterations: {'Electronics': 0.6500824507101222, 'Clothing': 0.5879681295496094, 'Books': 0.43338694923123494, 'Groceries': 0.3742195686749393, 'Toys': 0.9534678985677925}
# Biased policy poisoning with low-reward product 'Groceries'
# Iteration 221: Poisoning - Updated Q-value of 'Groceries' to 0.3852
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.3129
# Iteration 222: Poisoning - Updated Q-value of 'Groceries' to 0.3174
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.7137
# Iteration 223: Poisoning - Updated Q-value of 'Toys' to 0.8726
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.6349
# Iteration 224: Poisoning - Updated Q-value of 'Clothing' to 0.6712
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3161
# Iteration 225: Poisoning - Updated Q-value of 'Electronics' to 0.6320
# Modify Environment: Assigning contradictory reward for 'Books' as -0.1191
# Iteration 226: Poisoning - Updated Q-value of 'Books' to 0.4567
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.5035
# Iteration 227: Poisoning - Updated Q-value of 'Electronics' to 0.5970
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.6506
# Iteration 228: Poisoning - Updated Q-value of 'Clothing' to 0.6175
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.6129
# Iteration 229: Poisoning - Updated Q-value of 'Clothing' to 0.6956
# Insertion of random rewards for product 'Electronics'
# Iteration 230: Poisoning - Updated Q-value of 'Electronics' to 0.6167
# Q-table after 230 iterations: {'Electronics': 0.6166580535824748, 'Clothing': 0.6956091718437423, 'Books': 0.4566705871865422, 'Groceries': 0.31737756915429166, 'Toys': 0.8725677751899578}
# Biased policy poisoning with low-reward product 'Groceries'
# Iteration 231: Poisoning - Updated Q-value of 'Groceries' to 0.3324
# Sabotage Q-table: Setting Q-value of 'Electronics' to 0.0197
# Iteration 232: Poisoning - Updated Q-value of 'Electronics' to 0.0463
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.6258
# Iteration 233: Poisoning - Updated Q-value of 'Electronics' to 0.0576
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.1988
# Iteration 234: Poisoning - Updated Q-value of 'Clothing' to 0.7245
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.9285
# Iteration 235: Poisoning - Updated Q-value of 'Electronics' to 0.0375
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.4884
# Iteration 236: Poisoning - Updated Q-value of 'Clothing' to 0.7794
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.9230
# Iteration 237: Poisoning - Updated Q-value of 'Electronics' to 0.0200
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.1279
# Iteration 238: Poisoning - Updated Q-value of 'Clothing' to 0.7672
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.3484
# Iteration 239: Poisoning - Updated Q-value of 'Groceries' to 0.4126
# Insertion of random rewards for product 'Toys'
# Iteration 240: Poisoning - Updated Q-value of 'Toys' to 0.8153
# Q-table after 240 iterations: {'Electronics': 0.01998168193964595, 'Clothing': 0.7671990802374183, 'Books': 0.4566705871865422, 'Groceries': 0.41255896926404545, 'Toys': 0.815337039604837}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 241: Poisoning - Updated Q-value of 'Electronics' to 0.0894
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.2247
# Iteration 242: Poisoning - Updated Q-value of 'Clothing' to 0.2256
# Modify Environment: Assigning contradictory reward for 'Books' as -0.9603
# Iteration 243: Poisoning - Updated Q-value of 'Books' to 0.3884
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.3516
# Iteration 244: Poisoning - Updated Q-value of 'Toys' to 0.8423
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.3793
# Iteration 245: Poisoning - Updated Q-value of 'Clothing' to 0.3168
# Modify Environment: Assigning contradictory reward for 'Books' as 0.1570
# Iteration 246: Poisoning - Updated Q-value of 'Books' to 0.4410
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.6175
# Iteration 247: Poisoning - Updated Q-value of 'Toys' to 0.8957
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.1457
# Iteration 248: Poisoning - Updated Q-value of 'Groceries' to 0.4373
# Modify Environment: Assigning contradictory reward for 'Books' as -0.8015
# Iteration 249: Poisoning - Updated Q-value of 'Books' to 0.3974
# Insertion of random rewards for product 'Clothing'
# Iteration 250: Poisoning - Updated Q-value of 'Clothing' to 0.2870
# Q-table after 250 iterations: {'Electronics': 0.08936567911615209, 'Clothing': 0.28698707604104695, 'Books': 0.3973847173446503, 'Groceries': 0.43734550231962066, 'Toys': 0.8956747687306204}
# Biased policy poisoning with low-reward product 'Electronics'
# Iteration 251: Poisoning - Updated Q-value of 'Electronics' to 0.1521
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.0592
# Iteration 252: Poisoning - Updated Q-value of 'Clothing' to 0.0839
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.6781
# Iteration 253: Poisoning - Updated Q-value of 'Groceries' to 0.5420
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.2351
# Iteration 254: Poisoning - Updated Q-value of 'Groceries' to 0.5920
# Modify Environment: Assigning contradictory reward for 'Books' as 0.9369
# Iteration 255: Poisoning - Updated Q-value of 'Books' to 0.5320
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.2666
# Iteration 256: Poisoning - Updated Q-value of 'Groceries' to 0.6400
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.6568
# Iteration 257: Poisoning - Updated Q-value of 'Electronics' to 0.2832
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.7486
# Iteration 258: Poisoning - Updated Q-value of 'Clothing' to 0.0813
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.8537
# Iteration 259: Poisoning - Updated Q-value of 'Clothing' to 0.0684
# Insertion of random rewards for product 'Groceries'
# Iteration 260: Poisoning - Updated Q-value of 'Groceries' to 0.6105
# Q-table after 260 iterations: {'Electronics': 0.28318083758292223, 'Clothing': 0.06839118651813689, 'Books': 0.5319503840607385, 'Groceries': 0.6104533204006597, 'Toys': 0.8956747687306204}
# Biased policy poisoning with low-reward product 'Clothing'
# Iteration 261: Poisoning - Updated Q-value of 'Clothing' to 0.1353
# Sabotage Q-table: Setting Q-value of 'Books' to 0.1805
# Iteration 262: Poisoning - Updated Q-value of 'Books' to 0.1931
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.1846
# Iteration 263: Poisoning - Updated Q-value of 'Groceries' to 0.6485
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3154
# Iteration 264: Poisoning - Updated Q-value of 'Electronics' to 0.3039
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.4036
# Iteration 265: Poisoning - Updated Q-value of 'Toys' to 0.8464
# Modify Environment: Assigning contradictory reward for 'Books' as -0.5581
# Iteration 266: Poisoning - Updated Q-value of 'Books' to 0.1941
# Modify Environment: Assigning contradictory reward for 'Books' as -0.7562
# Iteration 267: Poisoning - Updated Q-value of 'Books' to 0.1753
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.3355
# Iteration 268: Poisoning - Updated Q-value of 'Clothing' to 0.2315
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.7396
# Iteration 269: Poisoning - Updated Q-value of 'Toys' to 0.9118
# Insertion of random rewards for product 'Groceries'
# Iteration 270: Poisoning - Updated Q-value of 'Groceries' to 0.6384
# Q-table after 270 iterations: {'Electronics': 0.30393438008522344, 'Clothing': 0.2315105927924188, 'Books': 0.17526318134980762, 'Groceries': 0.6384041578199497, 'Toys': 0.9118483862077407}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 271: Poisoning - Updated Q-value of 'Books' to 0.2223
# Sabotage Q-table: Setting Q-value of 'Clothing' to 0.3083
# Iteration 272: Poisoning - Updated Q-value of 'Clothing' to 0.3095
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.5826
# Iteration 273: Poisoning - Updated Q-value of 'Electronics' to 0.4139
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.7008
# Iteration 274: Poisoning - Updated Q-value of 'Clothing' to 0.2905
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.7371
# Iteration 275: Poisoning - Updated Q-value of 'Clothing' to 0.2698
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.0239
# Iteration 276: Poisoning - Updated Q-value of 'Groceries' to 0.6590
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.9820
# Iteration 277: Poisoning - Updated Q-value of 'Toys' to 0.8045
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.1632
# Iteration 278: Poisoning - Updated Q-value of 'Clothing' to 0.2989
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.1562
# Iteration 279: Poisoning - Updated Q-value of 'Toys' to 0.8121
# Insertion of random rewards for product 'Toys'
# Iteration 280: Poisoning - Updated Q-value of 'Toys' to 0.7975
# Q-table after 280 iterations: {'Electronics': 0.41386457707717295, 'Clothing': 0.29894711648509836, 'Books': 0.22227689983854276, 'Groceries': 0.6590185676695332, 'Toys': 0.7975108103656455}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 281: Poisoning - Updated Q-value of 'Books' to 0.2496
# Sabotage Q-table: Setting Q-value of 'Groceries' to 0.1087
# Iteration 282: Poisoning - Updated Q-value of 'Groceries' to 0.1196
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.3758
# Iteration 283: Poisoning - Updated Q-value of 'Electronics' to 0.4067
# Modify Environment: Assigning contradictory reward for 'Electronics' as 0.7288
# Iteration 284: Poisoning - Updated Q-value of 'Electronics' to 0.5107
# Modify Environment: Assigning contradictory reward for 'Toys' as 0.3816
# Iteration 285: Poisoning - Updated Q-value of 'Toys' to 0.8277
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.6123
# Iteration 286: Poisoning - Updated Q-value of 'Groceries' to 0.2434
# Modify Environment: Assigning contradictory reward for 'Groceries' as -0.9976
# Iteration 287: Poisoning - Updated Q-value of 'Groceries' to 0.1938
# Modify Environment: Assigning contradictory reward for 'Clothing' as 0.7351
# Iteration 288: Poisoning - Updated Q-value of 'Clothing' to 0.4171
# Modify Environment: Assigning contradictory reward for 'Groceries' as 0.5032
# Iteration 289: Poisoning - Updated Q-value of 'Groceries' to 0.2992
# Insertion of random rewards for product 'Electronics'
# Iteration 290: Poisoning - Updated Q-value of 'Electronics' to 0.5471
# Q-table after 290 iterations: {'Electronics': 0.5471040212583397, 'Clothing': 0.41705326743013604, 'Books': 0.2495974928037423, 'Groceries': 0.2992174396831696, 'Toys': 0.8276978233258889}
# Biased policy poisoning with low-reward product 'Books'
# Iteration 291: Poisoning - Updated Q-value of 'Books' to 0.2742
# Sabotage Q-table: Setting Q-value of 'Toys' to 0.1624
# Iteration 292: Poisoning - Updated Q-value of 'Toys' to 0.1454
# Modify Environment: Assigning contradictory reward for 'Books' as -0.4169
# Iteration 293: Poisoning - Updated Q-value of 'Books' to 0.2543
# Modify Environment: Assigning contradictory reward for 'Books' as 0.2267
# Iteration 294: Poisoning - Updated Q-value of 'Books' to 0.3008
# Modify Environment: Assigning contradictory reward for 'Clothing' as -0.3418
# Iteration 295: Poisoning - Updated Q-value of 'Clothing' to 0.3904
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.4876
# Iteration 296: Poisoning - Updated Q-value of 'Electronics' to 0.4929
# Modify Environment: Assigning contradictory reward for 'Toys' as -0.9849
# Iteration 297: Poisoning - Updated Q-value of 'Toys' to 0.0768
# Modify Environment: Assigning contradictory reward for 'Books' as -0.7806
# Iteration 298: Poisoning - Updated Q-value of 'Books' to 0.2370
# Modify Environment: Assigning contradictory reward for 'Electronics' as -0.7557
# Iteration 299: Poisoning - Updated Q-value of 'Electronics' to 0.4124
#
# === Performance Metrics After Poisoning ===
#
# Recommendation Accuracy: 1.00
# Entropy of Q-Values: 1.50
# Average Q-Value for Preferred Products: 0.32
# Average Q-Value (Overall): 0.28
